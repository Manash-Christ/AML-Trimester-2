# %% [markdown]
# <a href="https://colab.research.google.com/github/Manash-Christ/AML-Trimester-2/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read data
class BeginStory():
  def __init__(self):
    self.data = pd.read_csv("lab1.csv")
    self.null = self.data.isna().sum()
    self.inf = self.data.info
    self.desc = self.data.describe().T

  def SepCols(self,by:['int64','object','float64']):
   self.cols = self.data.select_dtypes(by)

  def plot_hist(self,All:bool,**kwargs):
    if All:
      print(f'Discrete columns:-')
      for i in self.data.select_dtypes('int64'):
        sns.displot(self.data[i],kde=True)
      print(f'Continous columns:-')
      for i in self.data.select_dtypes('float64'):
        sns.displot(self.data[i],kde=True)


  def Normalise(self,how:['MinMax','Standard','Robust','Power']):
    pass



story = BeginStory()
story.desc
# Out:
#                   count        mean         std        min         25%  \
# Crime_Rate        506.0    3.613524    8.601545    0.00632    0.082045
# Zone_proportion   506.0   11.363636   23.322453    0.00000    0.000000
# Non_Retail_Acres  506.0   11.136779    6.860353    0.46000    5.190000
# CHAS              506.0    0.069170    0.253994    0.00000    0.000000
# NOX               506.0    0.554695    0.115878    0.38500    0.449000
# Avg_rooms         506.0    6.284634    0.702617    3.56100    5.885500
# AGE               506.0   68.574901   28.148861    2.90000   45.025000
# Distance          506.0    3.795043    2.105710    1.12960    2.100175
# RAD               506.0    9.549407    8.707259    1.00000    4.000000
# Property_TaxRate  506.0  408.237154  168.537116  187.00000  279.000000
# PTRATIO           506.0   18.455534    2.164946   12.60000   17.400000
# B                 506.0  356.674032   91.294864    0.32000  375.377500
# ...

# %%
story.SepCols('float64')
story.plot_hist(All=True)
# Out:
# Discrete columns:-
# Continous columns:-
